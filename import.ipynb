# %%
import math
math.sqrt(64)
# Out:
# 8.0

# %%
from math import sqrt,pi
print(sqrt(64))
print(pi)
# Out:
# 8.0
# 3.141592653589793

# %%
import numpy as np
np.array([54,67,82,41])
# Out:
# array([54, 67, 82, 41])

# %%
##how to install own custom package:
from custom_package.maths import *
print(addition(78,69))
print(subtraction(12,40))
print(multiplication(99,100))
# Out:
# 147
# -28
# 9900
