# %%
import math
math.sqrt(64)
# Out:
# 8.0

# %%
from math import sqrt,pi
print(sqrt(64))
print(pi)
# Out:
# 8.0
# 3.141592653589793

# %%
import numpy as np
np.array([54,67,82,41])
# Out:
# array([54, 67, 82, 41])

# %%
##how to install own custom package:
from custom_package.maths import addition
addition(78,69)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 ##how to install own custom package:
# ----> 2 from custom_package.maths import addition
#       3 maths.addition(78,69)
#
# ModuleNotFoundError: No module named 'custom_package'
